# %%
pip install openpyxl #need to install to read my excel file
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Load any library I think I may need
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import requests
import PIL
import plotly
import plotly.express as px

# %%
file_path = "/Users/admin/visualization/02_activities/assignments/beer.xlsx" #beer file I download from internet

# Load the dataset into a DataFrame
df = pd.read_excel(file_path, engine="openpyxl")

# Display first few rows 
print(df.head())
print(df.columns)
# Out:
#            Type       Name                           Brand
# 0  Manufacturer  Amsterdam             Amsterdam Big Wheel
# 1  Manufacturer  Amsterdam           Amsterdam Blonde Beer
# 2  Manufacturer  Amsterdam              Amsterdam Frambois
# 3  Manufacturer  Amsterdam  Amsterdam Natural Blonde Lager
# 4  Manufacturer  Amsterdam         Amsterdam Natural Light
# Index(['Type', 'Name', 'Brand'], dtype='object')

# %%
# Create a line plot for Number of Names and Number of Brands per Beer Type
plt.figure(figsize=(10, 6))

# Plot lines for Number of Names and Number of Brands
sns.lineplot(data=filtered_type_counts, x="Type", y="Number of Names", marker='o', label="Number of Names", color="blue")
sns.lineplot(data=filtered_type_counts, x="Type", y="Number of Brands", marker='s', label="Number of Brands", color="orange")

# Labels and title
plt.xlabel("Beer Type")
plt.ylabel("Count")
plt.title("Names and Brands per Beer Type")
plt.legend()

# Display the line plot
plt.show()

# %% [markdown]
# See Excel Sheet called beer_barchart_option.xlsx for a bar chart version
